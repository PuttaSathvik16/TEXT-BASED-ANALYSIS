# %% [markdown]
# ## Classwork - 3 4/20/2024

# %% [markdown]
# ## TFIDF

# %%
import pandas as pd
file = "/Users/puttasathvik/Downloads/TextBasedAnalysis/ClassWork/un-general-debates-blueprint.csv"
df = pd.read_csv(file)
df.head(20)
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# 15       25  1970     DZA                          Algeria
# 16       25  1970     ECU                          Ecuador
# 17       25  1970     FRA                           France
# 18       25  1970     GBR                   United Kingdom
# 19       25  1970     GHA                            Ghana
#
#                   speaker    position  \
# 0                 Mr. NAS         NaN
# 1      Mr. DE PABLO PARDO         NaN
# 2             Mr. McMAHON         NaN
# 3      Mr. KIRCHSCHLAEGER         NaN
# 4              Mr. HARMEL         NaN
# 5          Mr. GURINOVICH         NaN
# 6      Mr. CAMACHO OMISTE         NaN
# 7      Mr. GIBSON BARBOZA         NaN
# 8               Mr. SHARP         NaN
# 9              Mr. AHIDJO  President
# 10            Mr. ICKONGA         NaN
# 11  Mr. VASQUEZ CARRIZOSA         NaN
# 12              Mr. FACIO         NaN
# 13            Mr. ALARCON         NaN
# 14        Mr FERNANDEZ G.
# 15              Mr. YAZID         NaN
# 16            Mr. Benites         NaN
# 17           Mr. SCHUMANN         NaN
# 18   Sir Alec DOUGLASHOME         NaN
# 19              Mr. OWUSU         NaN
#
#                                                  text
# 0   33: May I first convey to our President the co...
# 1   177.\t : It is a fortunate coincidence that pr...
# 2   100.\t  It is a pleasure for me to extend to y...
# 3   155.\t  May I begin by expressing to Ambassado...
# 4   176. No doubt each of us, before coming up to ...
# 5   \n71.\t. We are today mourning the untimely de...
# 6   135.\t  I wish to congratulate the President o...
# 7   1.\tMr. President, I should like, first of all...
# 8   \nThe General Assembly is fortunate indeed to ...
# 9   : A year ago I came here as the Acting Preside...
# 10  122.\t  I cannot begin my intervention without...
# 11  Mr. President, this visit to the United Nation...
# 12  62.\t  Mr. President, your election to the Pre...
# 13  1.\t  Mr. President, I should first like to co...
# 14  \n\n\n Mr. President, it was a source of great...
# 15  1.  The delegation of Algeria is very pleased ...
# 16  71.  It had been my hope that a loftier person...
# 17  84.\t  Within one month, when we celebrate the...
# 18  110.\t Mr. President, I should like first to s...
# 19  121.\t I should like to begin by congratulatin...

# %% [markdown]
# ## Get the stopwords

# %%
import nltk
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'as', 'all', 'each', "mustn't", 'i', 'am', 'after', 've', "needn't", 'against', "you'll", 'be', "couldn't", 'it', 'now', 'this', "wouldn't", 'some', 'those', 'how', 'hadn', 'what', 'who', 'y', "you'd", 'but', 'which', "that'll", 'just', 'won', 'wouldn', 'll', 'own', 'while', 'herself', "shan't", 'isn', 'very', 'itself', 'where', 'we', 'nor', 're', 'being', 'the', 'down', 'above', 'below', "it's", 'only', 'and', "don't", 'any', 'not', 'during', 'most', 'few', 'having', 'yourself', 'them', 'their', 'they', 'that', 'had', 'when', 'can', "isn't", 'd', 'myself', "hadn't", 'theirs', 'mightn', "mightn't", 's', 'once', 'about', 'to', 'or', 'have', 'ma', 'weren', 'was', 'an', 'at', 'both', 'did', "shouldn't", 'in', 'his', 'than', 'mustn', 'him', 't', 'me', 'before', 'he', 'more', 'your', 'hers', 'other', 'doesn', "won't", 'with', 'its', 'over', 'then', 'didn', "aren't", "weren't", 'shouldn', 'himself', 'these', 'under', 'is', 'too', 'shan', 'if', 'until', 'been', 'from', 'will', 'were', 'do', 'are', "didn't", 'no', 'aren', "you're", 'a', 'yours', "haven't", 'so', 'here', 'needn', 'wasn', 'off', 'through', 'hasn', 'our', 'she', 'same', 'don', "should've", 'up', 'does', 'by', 'yourselves', 'you', 'why', 'because', 'there', "hasn't", 'ourselves', 'for', 'into', 'haven', 'her', 'themselves', 'such', "you've", 'my', 'on', 'o', 'ours', "she's", "doesn't", 'ain', 'further', 'm', 'whom', 'should', 'between', 'has', 'couldn', 'out', 'doing', 'again', 'of', "wasn't"}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/puttasathvik/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Pre-processing pipeline

# %%
import regex as re
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]
pipeline = [str.lower, tokenize, remove_stop]
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# ## Now count the tokens

# %%
from collections import Counter
counter = Counter()
df['tokens'].map(counter.update)
freq_df = pd.DataFrame.from_dict(counter, 
orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'tokens'
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#                  freq
# tokens
# nations        124508
# united         120763
# international  117223
# world           89421
# countries       85734
# peace           72625
# development     62632
# states          59713
# people          59338
# security        58425

# %% [markdown]
# ## Now draw the word cloud

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt

# Increase the width and height for better resolution
wc = WordCloud(background_color='white', width=1080, height=1080, margin=2)

# Fit the words from your frequency dictionary
wc.fit_words(freq_df['freq'].to_dict())

# Create the figure with a larger size for better clarity
plt.figure(figsize=(10, 10), facecolor=None)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## Now let’s do the TFIDF and compare

# %%
import numpy as np
def compute_idf(df, column='tokens', preprocess=None, min_df=1):
 def update(doc):
   tokens = doc if preprocess is None else preprocess(doc)
   counter.update(set(tokens))
 # count tokens
 counter = Counter()
 df[column].map(update)
 # create data frame and compute idf
 idf_df = pd.DataFrame.from_dict(counter, orient='index', columns=['df'])
 idf_df = idf_df.query('df >= @min_df')
 idf_df['idf'] = np.log(len(df)/idf_df['df'])+0.1
 idf_df.index.name = 'token'
 return idf_df
idf_df = compute_idf(df)

# %% [markdown]
# ## TFIDF = TF * IDF

# %%
freq_df['tfidf'] = freq_df['freq'] * idf_df['idf']
freq_df.head()
# Out:
#                  freq         tfidf
# tokens
# nations        124508  12649.986284
# united         120763  12285.608632
# international  117223  12364.276226
# world           89421   9503.708982
# countries       85734  10888.485986

# %% [markdown]
# ## Let’s draw the word cloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Create the word cloud with higher resolution
wc = WordCloud(background_color='white', width=800, height=800, margin=2)
wc.fit_words(freq_df['tfidf'].to_dict())

# Display the word cloud
plt.figure(figsize=(10, 10), facecolor=None)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# Optionally, save the word cloud as a high-resolution image
wc.to_file("word_cloud.png")

# %% [markdown]
# ## Function to count the keywords

# %%
df['num_tokens'] = df['tokens'].map(len)
def count_keywords(tokens, keywords):
    tokens = [t for t in tokens if t in keywords]
    counter = Counter(tokens)
    return [counter.get(k, 0) for k in keywords]

# %% [markdown]
# ## Function to group by year

# %%
def count_keywords_by(df, by, keywords, column='tokens'):
    df = df.reset_index(drop=True)
# if the supplied dataframe has gaps inthe index
    freq_matrix = df[column].apply(count_keywords, keywords=keywords)
    freq_df = pd.DataFrame.from_records(freq_matrix,columns=keywords)
    freq_df[by] = df[by] 
# copy the grouping column(s)
    return freq_df.groupby(by=by).sum().sort_values(by)

# %% [markdown]
# ## Draw

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have already defined the count_keywords_by function and imported necessary libraries

keywords = ['terrorism', 'nuclear', 'war', 'oil', 'syria', 'afghanistan', 'refugees', 'israel', 'peacekeeping',
            'humanitarian', 'climate', 'soviet', 'russia', 'sustainable', 'egypt']

freq_df = count_keywords_by(df, by='year', keywords=keywords)

# Compute relative frequencies based on total number of tokens per year
freq_df = freq_df.div(df.groupby('year')['num_tokens'].sum(), axis=0)

# Apply square root as sublinear filter for better contrast
freq_df = freq_df.apply(np.sqrt)

plt.figure(figsize=(15, 7))
sns.set(font_scale=1)
sns.heatmap(data=freq_df.T, xticklabels=True, yticklabels=True, cbar=False, cmap="Reds")
sns.set(font_scale=1)

# %% [markdown]
# ## 1970:

# %%
import pandas as pd
file = "/Users/puttasathvik/Downloads/TextBasedAnalysis/ClassWork/un-general-debates-blueprint.csv"
df = pd.read_csv(file)
df= df[df['year']==1970]
df.head(20)
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# 15       25  1970     DZA                          Algeria
# 16       25  1970     ECU                          Ecuador
# 17       25  1970     FRA                           France
# 18       25  1970     GBR                   United Kingdom
# 19       25  1970     GHA                            Ghana
#
#                   speaker    position  \
# 0                 Mr. NAS         NaN
# 1      Mr. DE PABLO PARDO         NaN
# 2             Mr. McMAHON         NaN
# 3      Mr. KIRCHSCHLAEGER         NaN
# 4              Mr. HARMEL         NaN
# 5          Mr. GURINOVICH         NaN
# 6      Mr. CAMACHO OMISTE         NaN
# 7      Mr. GIBSON BARBOZA         NaN
# 8               Mr. SHARP         NaN
# 9              Mr. AHIDJO  President
# 10            Mr. ICKONGA         NaN
# 11  Mr. VASQUEZ CARRIZOSA         NaN
# 12              Mr. FACIO         NaN
# 13            Mr. ALARCON         NaN
# 14        Mr FERNANDEZ G.
# 15              Mr. YAZID         NaN
# 16            Mr. Benites         NaN
# 17           Mr. SCHUMANN         NaN
# 18   Sir Alec DOUGLASHOME         NaN
# 19              Mr. OWUSU         NaN
#
#                                                  text
# 0   33: May I first convey to our President the co...
# 1   177.\t : It is a fortunate coincidence that pr...
# 2   100.\t  It is a pleasure for me to extend to y...
# 3   155.\t  May I begin by expressing to Ambassado...
# 4   176. No doubt each of us, before coming up to ...
# 5   \n71.\t. We are today mourning the untimely de...
# 6   135.\t  I wish to congratulate the President o...
# 7   1.\tMr. President, I should like, first of all...
# 8   \nThe General Assembly is fortunate indeed to ...
# 9   : A year ago I came here as the Acting Preside...
# 10  122.\t  I cannot begin my intervention without...
# 11  Mr. President, this visit to the United Nation...
# 12  62.\t  Mr. President, your election to the Pre...
# 13  1.\t  Mr. President, I should first like to co...
# 14  \n\n\n Mr. President, it was a source of great...
# 15  1.  The delegation of Algeria is very pleased ...
# 16  71.  It had been my hope that a loftier person...
# 17  84.\t  Within one month, when we celebrate the...
# 18  110.\t Mr. President, I should like first to s...
# 19  121.\t I should like to begin by congratulatin...

# %% [markdown]
# ## Get the stopwords

# %%
import nltk
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'as', 'all', 'each', "mustn't", 'i', 'am', 'after', 've', "needn't", 'against', "you'll", 'be', "couldn't", 'it', 'now', 'this', "wouldn't", 'some', 'those', 'how', 'hadn', 'what', 'who', 'y', "you'd", 'but', 'which', "that'll", 'just', 'won', 'wouldn', 'll', 'own', 'while', 'herself', "shan't", 'isn', 'very', 'itself', 'where', 'we', 'nor', 're', 'being', 'the', 'down', 'above', 'below', "it's", 'only', 'and', "don't", 'any', 'not', 'during', 'most', 'few', 'having', 'yourself', 'them', 'their', 'they', 'that', 'had', 'when', 'can', "isn't", 'd', 'myself', "hadn't", 'theirs', 'mightn', "mightn't", 's', 'once', 'about', 'to', 'or', 'have', 'ma', 'weren', 'was', 'an', 'at', 'both', 'did', "shouldn't", 'in', 'his', 'than', 'mustn', 'him', 't', 'me', 'before', 'he', 'more', 'your', 'hers', 'other', 'doesn', "won't", 'with', 'its', 'over', 'then', 'didn', "aren't", "weren't", 'shouldn', 'himself', 'these', 'under', 'is', 'too', 'shan', 'if', 'until', 'been', 'from', 'will', 'were', 'do', 'are', "didn't", 'no', 'aren', "you're", 'a', 'yours', "haven't", 'so', 'here', 'needn', 'wasn', 'off', 'through', 'hasn', 'our', 'she', 'same', 'don', "should've", 'up', 'does', 'by', 'yourselves', 'you', 'why', 'because', 'there', "hasn't", 'ourselves', 'for', 'into', 'haven', 'her', 'themselves', 'such', "you've", 'my', 'on', 'o', 'ours', "she's", "doesn't", 'ain', 'further', 'm', 'whom', 'should', 'between', 'has', 'couldn', 'out', 'doing', 'again', 'of', "wasn't"}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/puttasathvik/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Pre-processing pipeline

# %%
import regex as re
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]
pipeline = [str.lower, tokenize, remove_stop]
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# ## Now count the tokens

# %%
from collections import Counter
counter = Counter()
df['tokens'].map(counter.update)
freq_df = pd.DataFrame.from_dict(counter, 
orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'tokens'
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#                freq
# tokens
# nations        1997
# united         1996
# international  1251
# world          1093
# peace           970
# countries       908
# states          896
# organization    762
# would           677
# people          649

# %% [markdown]
# ## Now draw the word cloud

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt
wc = WordCloud(background_color='white', width = 1080, height=1080, margin=2)
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %% [markdown]
# ## Now let’s do the TFIDF and compare

# %%
import numpy as np
def compute_idf(df, column='tokens', preprocess=None, min_df=1):
 def update(doc):
   tokens = doc if preprocess is None else preprocess(doc)
   counter.update(set(tokens))
 # count tokens
 counter = Counter()
 df[column].map(update)
 # create data frame and compute idf
 idf_df = pd.DataFrame.from_dict(counter, orient='index', columns=['df'])
 idf_df = idf_df.query('df >= @min_df')
 idf_df['idf'] = np.log(len(df)/idf_df['df'])+0.1
 idf_df.index.name = 'token'
 return idf_df
idf_df = compute_idf(df)

# %% [markdown]
# ## TFIDF = TF * IDF

# %%
freq_df['tfidf'] = freq_df['freq'] * idf_df['idf']
freq_df.head()
# Out:
#                freq  tfidf
# tokens
# nations        1997  199.7
# united         1996  199.6
# international  1251  125.1
# world          1093  109.3
# peace           970   97.0

# %% [markdown]
# ## Let’s draw the word cloud

# %%
wc = WordCloud(background_color='white', width = 1080, height=1080,margin=2)
wc.fit_words(freq_df['tfidf'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tfidf'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 2
#       1 wc = WordCloud(background_color='white', width = 1080, height=1080,margin=2)
# ----> 2 wc.fit_words(freq_df['tfidf'].to_dict() )
#       3 plt.figure(figsize = (8, 8), facecolor = None)
#       4 plt.imshow(wc)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'tfidf'

# %% [markdown]
# ## Function to count the keywords

# %%
df['num_tokens'] = df['tokens'].map(len)
def count_keywords(tokens, keywords):
    tokens = [t for t in tokens if t in keywords]
    counter = Counter(tokens)
    return [counter.get(k, 0) for k in keywords]

# %% [markdown]
# ## Function to group by year

# %%
def count_keywords_by(df, by, keywords, column='tokens'):
    df = df.reset_index(drop=True)
# if the supplied dataframe has gaps inthe index
    freq_matrix = df[column].apply(count_keywords, keywords=keywords)
    freq_df = pd.DataFrame.from_records(freq_matrix,columns=keywords)
    freq_df[by] = df[by] 
# copy the grouping column(s)
    return freq_df.groupby(by=by).sum().sort_values(by)

# %% [markdown]
# ## Draw

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have already defined the count_keywords_by function and imported necessary libraries

keywords = ['terrorism', 'nuclear', 'war', 'oil', 'syria', 'afghanistan', 'refugees', 'israel', 'peacekeeping',
            'humanitarian', 'climate', 'soviet', 'russia', 'sustainable', 'egypt']

freq_df = count_keywords_by(df, by='year', keywords=keywords)

# Compute relative frequencies based on total number of tokens per year
freq_df = freq_df.div(df.groupby('year')['num_tokens'].sum(), axis=0)

# Apply square root as sublinear filter for better contrast
freq_df = freq_df.apply(np.sqrt)

plt.figure(figsize=(15, 7))
sns.set(font_scale=1)
sns.heatmap(data=freq_df.T, xticklabels=True, yticklabels=True, cbar=False, cmap="Reds")
sns.set(font_scale=1)

# %% [markdown]
# ## 2015:

# %%
import pandas as pd
file = "/Users/puttasathvik/Downloads/TextBasedAnalysis/ClassWork/un-general-debates-blueprint.csv"
df = pd.read_csv(file)
df= df[df['year']==2015]
df.head(20)
# Out:
#       session  year country            country_name  \
# 7314       70  2015     AFG             Afghanistan
# 7315       70  2015     AGO                  Angola
# 7316       70  2015     ALB                 Albania
# 7317       70  2015     AND                 Andorra
# 7318       70  2015     ARE    United Arab Emirates
# 7319       70  2015     ARG               Argentina
# 7320       70  2015     ARM                 Armenia
# 7321       70  2015     ATG     Antigua and Barbuda
# 7322       70  2015     AUS               Australia
# 7323       70  2015     AUT                 Austria
# 7324       70  2015     AZE              Azerbaijan
# 7325       70  2015     BDI                 Burundi
# 7326       70  2015     BEL                 Belgium
# 7327       70  2015     BEN                   Benin
# 7328       70  2015     BFA            Burkina Faso
# 7329       70  2015     BGD              Bangladesh
# 7330       70  2015     BGR                Bulgaria
# 7331       70  2015     BHR                 Bahrain
# 7332       70  2015     BHS                 Bahamas
# 7333       70  2015     BIH  Bosnia and Herzegovina
#
#                                   speaker                      position  \
# 7314                Mr. Abdullah Abdullah       Chief Executive Officer
# 7315          Mr. Manuel Domingos Vicente                vice-President
# 7316                         Mr. Edi Rama                Prime minister
# 7317               Mr. Antoni Martí Petit            Head of Government
# 7318  Sheikh Abdullah Bin Zayed Al Nahyan  Minister for Foreign Affairs
# 7319                   Cristina Fernández                     President
# 7320                   Mr. Serzh Sargsyan                     President
# 7321           Mr. Gaston Alphonso Browne                Prime minister
# 7322                     Ms. Julie Bishop  Minister for Foreign Affairs
# 7323                   Mr. Sebastian Kurz  Minister for Foreign Affairs
# 7324  Mr. Elmar Maharram oglu Mammadyarov  Minister for Foreign Affairs
# 7325                    Mr. Joseph Butore                Vice-President
# 7326                   Mr. Charles Michel                Prime minister
# 7327                    Mr. Lionel Zinsou                Prime minister
# 7328                   Mr. Michel Kafando                     President
# 7329                        Sheikh Hasina                Prime minister
# 7330                 Mr. Rosen Plevneliev                     President
# 7331   Shaikh Khalid Bin Ahmed Al-Khalifa  Minister for Foreign Affairs
# 7332            Mr. Frederick A. Mitchell  Minister for Foreign Affairs
# 7333                     Mr. Dragan Čović                     President
#
#                                                    text
# 7314  It gives me great pleasure, on behalf of the I...
# 7315  At the outset, on behalf of the President of A...
# 7316  One year ago, Pope Francis began his visits ar...
# 7317  It is my honour to represent my country, the P...
# 7318  It is my pleasure to congratulate Mr. Mogens L...
# 7319  At the outset, allow me to welcome a very rele...
# 7320  I congratulate you, Mr. President, on your ele...
# 7321  Democracy, peace, security, rule of law and re...
# 7322  We meet this day at an important time for the ...
# 7323  Seventy years ago, the United Nations was foun...
# 7324  At the outset, I should like to congratulate M...
# 7325  I would like first to thank God Almighty for g...
# 7326  A predecessor of the President of the General ...
# 7327  The Organization turns 70 this year, and on th...
# 7328  It is my honour to address the Assembly as Pre...
# 7329  Let me extend my heartiest felicitations to Mr...
# 7330  Allow me to congratulate you, Mr. President, o...
# 7331  At the outset, it is my pleasure to warmly con...
# 7332  I bring you, Sir, and the Assembly warm frater...
# 7333  Six days ago, world leaders, who gathered in t...

# %% [markdown]
# ## Get the stopwords

# %%
import nltk
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'as', 'all', 'each', "mustn't", 'i', 'am', 'after', 've', "needn't", 'against', "you'll", 'be', "couldn't", 'it', 'now', 'this', "wouldn't", 'some', 'those', 'how', 'hadn', 'what', 'who', 'y', "you'd", 'but', 'which', "that'll", 'just', 'won', 'wouldn', 'll', 'own', 'while', 'herself', "shan't", 'isn', 'very', 'itself', 'where', 'we', 'nor', 're', 'being', 'the', 'down', 'above', 'below', "it's", 'only', 'and', "don't", 'any', 'not', 'during', 'most', 'few', 'having', 'yourself', 'them', 'their', 'they', 'that', 'had', 'when', 'can', "isn't", 'd', 'myself', "hadn't", 'theirs', 'mightn', "mightn't", 's', 'once', 'about', 'to', 'or', 'have', 'ma', 'weren', 'was', 'an', 'at', 'both', 'did', "shouldn't", 'in', 'his', 'than', 'mustn', 'him', 't', 'me', 'before', 'he', 'more', 'your', 'hers', 'other', 'doesn', "won't", 'with', 'its', 'over', 'then', 'didn', "aren't", "weren't", 'shouldn', 'himself', 'these', 'under', 'is', 'too', 'shan', 'if', 'until', 'been', 'from', 'will', 'were', 'do', 'are', "didn't", 'no', 'aren', "you're", 'a', 'yours', "haven't", 'so', 'here', 'needn', 'wasn', 'off', 'through', 'hasn', 'our', 'she', 'same', 'don', "should've", 'up', 'does', 'by', 'yourselves', 'you', 'why', 'because', 'there', "hasn't", 'ourselves', 'for', 'into', 'haven', 'her', 'themselves', 'such', "you've", 'my', 'on', 'o', 'ours', "she's", "doesn't", 'ain', 'further', 'm', 'whom', 'should', 'between', 'has', 'couldn', 'out', 'doing', 'again', 'of', "wasn't"}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/puttasathvik/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Pre-processing pipeline

# %%
import regex as re
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]
pipeline = [str.lower, tokenize, remove_stop]
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# ## Now count the tokens

# %%
from collections import Counter
counter = Counter()
df['tokens'].map(counter.update)
freq_df = pd.DataFrame.from_dict(counter, 
orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'tokens'
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#                freq
# tokens
# nations        2587
# united         2571
# development    1754
# international  1727
# world          1635
# security       1391
# peace          1281
# people         1229
# countries      1086
# must           1033

# %% [markdown]
# ## Now draw the word cloud

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt
wc = WordCloud(background_color='white', width = 1080, height=1080, margin=2)
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %% [markdown]
# ## Now let’s do the TFIDF and compare

# %%
import numpy as np
def compute_idf(df, column='tokens', preprocess=None, min_df=1):
 def update(doc):
   tokens = doc if preprocess is None else preprocess(doc)
   counter.update(set(tokens))
 # count tokens
 counter = Counter()
 df[column].map(update)
 # create data frame and compute idf
 idf_df = pd.DataFrame.from_dict(counter, orient='index', columns=['df'])
 idf_df = idf_df.query('df >= @min_df')
 idf_df['idf'] = np.log(len(df)/idf_df['df'])+0.1
 idf_df.index.name = 'token'
 return idf_df
idf_df = compute_idf(df)

# %% [markdown]
# ## TFIDF = TF * IDF

# %%
freq_df['tfidf'] = freq_df['freq'] * idf_df['idf']
freq_df.head()
# Out:
#                freq       tfidf
# tokens
# nations        2587  258.700000
# united         2571  257.100000
# development    1754  249.654474
# international  1727  208.868861
# world          1635  180.531404

# %% [markdown]
# ## Let’s draw the word cloud

# %%
wc = WordCloud(background_color='white', width = 1080, height=1080,margin=2)
wc.fit_words(freq_df['tfidf'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %% [markdown]
# ## Function to count the keywords

# %%
df['num_tokens'] = df['tokens'].map(len)
def count_keywords(tokens, keywords):
    tokens = [t for t in tokens if t in keywords]
    counter = Counter(tokens)
    return [counter.get(k, 0) for k in keywords]

# %% [markdown]
# ## Function to group by year

# %%
def count_keywords_by(df, by, keywords, column='tokens'):
    df = df.reset_index(drop=True)
# if the supplied dataframe has gaps inthe index
    freq_matrix = df[column].apply(count_keywords, keywords=keywords)
    freq_df = pd.DataFrame.from_records(freq_matrix,columns=keywords)
    freq_df[by] = df[by] 
# copy the grouping column(s)
    return freq_df.groupby(by=by).sum().sort_values(by)

# %% [markdown]
# ## Draw

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have already defined the count_keywords_by function and imported necessary libraries

keywords = ['terrorism', 'nuclear', 'war', 'oil', 'syria', 'afghanistan', 'refugees', 'israel', 'peacekeeping',
            'humanitarian', 'climate', 'soviet', 'russia', 'sustainable', 'egypt']

freq_df = count_keywords_by(df, by='year', keywords=keywords)

# Compute relative frequencies based on total number of tokens per year
freq_df = freq_df.div(df.groupby('year')['num_tokens'].sum(), axis=0)

# Apply square root as sublinear filter for better contrast
freq_df = freq_df.apply(np.sqrt)

plt.figure(figsize=(15, 7))
sns.set(font_scale=1)
sns.heatmap(data=freq_df.T, xticklabels=True, yticklabels=True, cbar=False, cmap="Reds")
sns.set(font_scale=1)
